# %% [markdown]
# # p.1 Tokenizing words and Sentences

# %%
from IPython.display import YouTubeVideo
# a talk about IPython at Sage Days at U. Washington, Seattle.
# Video credit: William Stein.
YouTubeVideo('FLZvOKSCkxY')

# %% [markdown]
# ## 1. Preparation
#
# ### 1.1 Install Python 3.
#
# It is recommended that you download and install Anaconda from https://www.continuum.io/downloads.
#
# ### 1.2 Install the nltk package in the conda nltk environment.
#
# ```bash
# # Activate the nltk environment.
# $ conda activate nltk
#
# # Install the nltk package.
# $ conda install nltk
# ```
#
# or
#
# ```bash
# $ conda install -n nltk nltk
# ```
#
# ### 1.3 Download nltk data.
#
# In a terminal, type "python" and then
#
# ```python
# import nltk
# nltk.download()
# ```
#
# A GUI should pop up and select **"all"** to download all data packages.

# %% [markdown]
# ## 2. Terminology
#
# ### 2.1 Tokenizing
#
# (1) Word tokenizer
#
# (2) Sentence tokenizer
#
# ### 2.2 Corpora
#
# Body of text, e.g., medical corpora, presidential speeches, English language
#
# ### 2.3 Lexicon
#
# (1) Dictionary with contexts
#
# (2) Words and their means
#
# (3) Investor-speak vs regular english-speak
#
# Investor-speak "bull" = someone who is positive about the market
# Regular english-speak "bull" = scary animal you don't want running @ you
#
# ## 3. Examples
#
# ### 3.1 Tokenizing

# %%
from nltk.tokenize import sent_tokenize, word_tokenize

# tokenizing - word tokenizers.... sentence tokenizers
# lexicon and corporas
# corpora - body of text. ex: medical journals, presidential speeches, English language
# lexicon - words and their means

# investor-speak.... regular english-speak

# investor speak 'bull' = someone who is positive about the market
# english-speak 'bull' = scary animal you don't want running @ you

example_text = "Hello Mr. Smith, how are you doing today? The weather is great and Python is awesome. The sky is pinkish-blue. You should not eat cardboard."

##print(sent_tokenize(example_text))
##
##print(word_tokenize(example_text))

for i in word_tokenize(example_text):
    print(i)
# Out:
# Hello
# Mr.
# Smith
# ,
# how
# are
# you
# doing
# today
# ?
# The
# weather
# is
# great
# and
# Python
# is
# awesome
# .
# The
# sky
# is
# pinkish-blue
# .
# You
# should
# not
# eat
# cardboard
# .
