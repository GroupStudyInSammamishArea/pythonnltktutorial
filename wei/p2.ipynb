# %% [markdown]
# # p.2 Stop Words

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('w36-U-ccajM')

# %% [markdown]
# ## 1. Definition
#
# "Useless words"
#
# ### 1.1 Some word that indicates a discontinuance of analysis
#
# ### 1.2 Some word that has nothing to do with the analysis
#
# a, the, and...

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

example_sentence = "This is an example showing off stop word filtration."

stop_words = set(stopwords.words("english"))

print(stop_words)

words = word_tokenize(example_sentence)

# filtered_sentence = []

# for w in words:
#     if w not in stop_words:
#         filtered_sentence.append(w)
        
# print(filtered_sentence)
# Out:
# {'you', 'under', 'very', 'does', "mightn't", "shan't", "she's", 'is', "wasn't", "should've", 'above', 'now', "isn't", "didn't", 'any', 'me', 'themselves', "haven't", 'how', 'should', 'didn', "shouldn't", 'own', 'd', 'are', 'just', 'has', 'did', 't', 'couldn', 'be', 'weren', "you've", 'once', 'those', 'ours', 'hasn', 'or', 'have', 'an', 'theirs', 'she', 'while', 'so', 'through', 'than', 'whom', 's', "couldn't", 'mustn', 'a', "don't", 'and', 'wasn', "wouldn't", 'my', "mustn't", 'again', 'some', "that'll", 'over', 'it', 'do', 'ourselves', 'of', 'further', 'no', 'having', 'don', 'each', 'before', "doesn't", 'doing', 'down', 'i', 'was', 'most', 'we', 'm', "you're", 'aren', 'isn', 'them', 'on', 'himself', 'y', 'needn', 'our', 'yourself', 'll', 'all', 've', 'why', 'her', 'won', 'which', 'its', 'more', 'yours', 'mightn', 'but', 'he', "aren't", 'with', 'in', 'by', 'both', 'his', "won't", 'such', 'about', 'against', 'during', 'had', 'below', 'that', 'him', 'who', 'up', 're', 'other', 'not', "hadn't", 'where', 'if', "it's", 'o', 'because', 'at', 'being', 'here', "weren't", 'same', 'can', 'into', 'shouldn', 'these', 'shan', 'ain', 'what', 'then', 'myself', 'out', 'when', 'they', 'hadn', 'am', 'hers', 'from', "you'll", 'there', 'were', 'nor', "you'd", 'itself', 'their', 'until', 'for', 'after', 'few', 'been', 'herself', "hasn't", 'too', 'doesn', 'to', 'off', 'this', 'between', 'haven', 'will', 'yourselves', "needn't", 'only', 'your', 'ma', 'the', 'as', 'wouldn'}
# ['This', 'example', 'showing', 'stop', 'word', 'filtration', '.']
